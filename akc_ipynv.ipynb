# %%
import pandas as pd
import numpy as np
import re

from sklearn.preprocessing import (
    OneHotEncoder, 
    StandardScaler, 
    OrdinalEncoder
)
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.neighbors import NearestNeighbors


#LOAD THE DATA
df = pd.read_csv("akc-data-latest.csv")  
print("Data loaded. Shape:", df.shape)

# Check columns
print("Columns in the dataset:", df.columns.tolist())
df.head()
# Out:
# Data loaded. Shape: (277, 21)
# Columns in the dataset: ['Unnamed: 0', 'description', 'temperament', 'popularity', 'min_height', 'max_height', 'min_weight', 'max_weight', 'min_expectancy', 'max_expectancy', 'group', 'grooming_frequency_value', 'grooming_frequency_category', 'shedding_value', 'shedding_category', 'energy_level_value', 'energy_level_category', 'trainability_value', 'trainability_category', 'demeanor_value', 'demeanor_category']
#          Unnamed: 0                                        description  \
# 0     Affenpinscher  The Affen’s apish look has been described many...
# 1      Afghan Hound  The Afghan Hound is an ancient breed, his whol...
# 2  Airedale Terrier  The Airedale Terrier is the largest of all ter...
# 3             Akita  Akitas are burly, heavy-boned spitz-type dogs ...
# 4  Alaskan Malamute  The Alaskan Malamute stands 23 to 25 inches at...
#
#                                  temperament popularity  min_height  \
# 0        Confident, Famously Funny, Fearless        148       22.86
# 1  Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 2               Friendly, Clever, Courageous         60       58.42
# 3    Courageous, Dignified, Profoundly Loyal         47       60.96
# 4               Affectionate, Loyal, Playful         58       58.42
#
#    max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 0       29.21    3.175147    4.535924            12.0            15.0  ...
# 1       68.58   22.679619   27.215542            12.0            15.0  ...
# 2       58.42   22.679619   31.751466            11.0            14.0  ...
# 3       71.12   31.751466   58.967008            10.0            13.0  ...
# 4       63.50   34.019428   38.555351            10.0            14.0  ...
#
#   grooming_frequency_value  grooming_frequency_category shedding_value  \
# 0                      0.6    2-3 Times a Week Brushing            0.6
# 1                      0.8               Daily Brushing            0.2
# 2                      0.6    2-3 Times a Week Brushing            0.4
# 3                      0.8               Daily Brushing            0.6
# 4                      0.6    2-3 Times a Week Brushing            0.6
#
#    shedding_category energy_level_value  energy_level_category  \
# 0           Seasonal                0.6       Regular Exercise
# 1         Infrequent                0.8              Energetic
# 2         Occasional                0.6       Regular Exercise
# 3           Seasonal                0.8              Energetic
# 4           Seasonal                0.8              Energetic
#
#   trainability_value  trainability_category demeanor_value  demeanor_category
# 0                0.8          Easy Training            1.0           Outgoing
# 1                0.2        May be Stubborn            0.2         Aloof/Wary
# 2                1.0        Eager to Please            0.8           Friendly
# 3                1.0        Eager to Please            0.6   Alert/Responsive
# 4                0.4            Independent            0.8           Friendly
#
# [5 rows x 21 columns]

# %%
# Compute average weight and height and expectancy
df["weight_avg"] = (df["min_weight"] + df["max_weight"]) / 2
df["height_avg"] = (df["min_height"] + df["max_height"]) / 2
df["life_expectancy_avg"] = (df["min_expectancy"] + df["max_expectancy"]) / 2

print(df[["min_weight", "max_weight", "weight_avg"]].head())
# Out:
#    min_weight  max_weight  weight_avg
# 0    3.175147    4.535924    3.855535
# 1   22.679619   27.215542   24.947580
# 2   22.679619   31.751466   27.215542
# 3   31.751466   58.967008   45.359237
# 4   34.019428   38.555351   36.287390

# %%
numeric_features = [
    "weight_avg", 
    "height_avg", 
    "life_expectancy_avg", 
    "popularity",                   
    "grooming_frequency_value",     
    "shedding_value",              
    "energy_level_value",           
    "trainability_value",           
    "demeanor_value"                
]

# %%
categorical_features = [
    "group",              
    "grooming_frequency_category",
    "shedding_category",
    "energy_level_category",
    "trainability_category",
    "demeanor_category",
    
    
]

# %%
#CLEAN MISSING DATA
all_features_needed = numeric_features + categorical_features
df_clean = df.dropna(subset=all_features_needed).copy()
df_clean = df_clean[df_clean["popularity"] != "of"]

# %%
for col in numeric_features:
    # Look for non-numeric entries in this column
    non_numeric_mask = pd.to_numeric(df_clean[col], errors="coerce").isna()
    if non_numeric_mask.any():
        print(f"Column '{col}' has non-numeric values:")
        print(df_clean.loc[non_numeric_mask, col].unique())

# %%
preprocessor = ColumnTransformer(transformers=[
    ("num", StandardScaler(), numeric_features),
    ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
])

# %%
X = preprocessor.fit_transform(df_clean)

# %%
nn_model = NearestNeighbors(n_neighbors=5, metric="euclidean")
nn_model.fit(X)
print("Nearest Neighbors model is fitted.")
# Out:
# Nearest Neighbors model is fitted.

# %%
def recommend_dogs(preferences, k=5):
    """
    return the top-k nearest rows from df_clean.
    """
    
    # Turn 'preferences' into a single-row DataFrame then Fill in any missing features with a default or the mean/mode
    row_dict = {}
    for col in all_features_needed:
        if col in preferences:
            row_dict[col] = [preferences[col]]
        else:
           
            if col in numeric_features:
                row_dict[col] = [df_clean[col].mean()]
            else:
                # for categorical, pick the most frequent group
                row_dict[col] = [df_clean[col].mode()[0]]
    
    single_row_df = pd.DataFrame(row_dict)
    
    X_single = preprocessor.transform(single_row_df)
    
    #nearest neighbors
    distances, indices = nn_model.kneighbors(X_single, n_neighbors=k)
    

    recs = df_clean.iloc[indices[0]].copy()
    recs["KNN_distance"] = distances[0]
    return recs

# %% [markdown]
# Using

# %%
adopter_preferences = {
    "weight_avg": 20,                  # they'd like around 20 (units: lbs or kg depending on your dataset)
    "height_avg": 30,                  # they'd like around 30 cm/in
    "life_expectancy_avg": 12,         # they'd like a dog who lives ~12 years
    "popularity": 50,                  # just an example usage
    "grooming_frequency_value": 2,     # they'd prefer lower grooming needs
    "energy_level_value": 3,           # moderate energy
    "group": "Sporting"                # they want a sporting group dog
    
}

recommendations = recommend_dogs(adopter_preferences, k=30)
print("Recommended dogs for these preferences:")
print(recommendations)
# Out:
# Recommended dogs for these preferences:
#                              Unnamed: 0  \
# 57                             Brittany
# 46                        Border Collie
# 136                        Irish Setter
# 216                     Russell Terrier
# 180  Nova Scotia Duck Tolling Retriever
# 271         Wirehaired Pointing Griffon
# 184              Parson Russell Terrier
# 108                       Finnish Spitz
# 120                    Golden Retriever
# 122        Grand Basset Griffon Vendéen
# 264                          Weimaraner
# 28                            Beauceron
# 121                       Gordon Setter
# 138                 Irish Water Spaniel
# 115          German Shorthaired Pointer
# 129                             Harrier
# 109               Flat-Coated Retriever
# 203                Portuguese Water Dog
# 124                      Great Pyrenees
# 243                   Spanish Water Dog
# 117           German Wirehaired Pointer
# 153                  Labrador Retriever
# 50                 Bouvier des Flandres
# 165         Miniature American Shepherd
# 26                               Beagle
# 3                                 Akita
# 113                     German Pinscher
# 40                Black Russian Terrier
# 193             Polish Lowland Sheepdog
# 221                             Samoyed
#
#                                            description  \
# 57   Brittanys are smaller than setters but leggier...
# 46   Borders are athletic, medium-sized herders sta...
# 136  The Irish Setter has been described by its par...
# 216  These jaunty little fellows pack lots of perso...
# 180  The little gundog with the big name is the sma...
# 271  Griffs are medium-sized, all-purpose gundogs s...
# 184  PRTs stand 12–15 inches at the shoulder, and w...
# 108  The balanced, squarely symmetrical Finnish Spi...
# 120  The Golden Retriever is a sturdy, muscular dog...
# 122  First, let’s deal with the name. Roughly trans...
# 264  Instantly recognized by a distinctive silvery-...
# 28   Beaucerons are muscular, rugged, and large, st...
# 121  Gordons are the largest and most substantial o...
# 138  Standing 21 to 24 inches at the shoulder and w...
# 115  Male German Shorthaired Pointers stand between...
# 129  Somewhat resembling a Beagle with a gym member...
# 109  The Flat-Coated Retriever’s eponymous flat-lyi...
# 203  The Portuguese Water Dog is super-smart and ve...
# 124  Frequently described as “majestic,” Pyrs are b...
# 243  The unique look of these inexhaustible workers...
# 117  Standing as high as 26 inches at the shoulder,...
# 153  The sturdy, well-balanced Labrador Retriever c...
# 50   Standing as high as 27.5 inches, with heavy bo...
# 165  The Miniature American Shepherd shares many ph...
# 26   There are two Beagle varieties: those standing...
# 3    Akitas are burly, heavy-boned spitz-type dogs ...
# 113  Sleek, shiny, and streamlined, German Pinscher...
# 40   What’s the word we’re looking for? Imposing? M...
# 193  First, about that nickname: PON is the acronym...
# 221  Samoyeds, the smiling sledge dogs, were bred f...
#
#                                            temperament popularity  min_height  \
# 57                          Bright, Fun-Loving, Upbeat         26      44.450
# 46                      Affectionate, Smart, Energetic         35      45.720
# 136                    Active, Outgoing, Sweet-Natured         77      63.500
# 216                         Alert, Inquisitive, Lively         82      25.400
# 180                Affectionate, Intelligent, Outgoing         83      43.180
# 271                       Friendly, Devoted, Trainable         65      50.800
# 184                         Friendly, Clever, Athletic        117      33.020
# 108                     Friendly, Good-Natured, Lively        184      39.370
# 120                     Friendly, Intelligent, Devoted          3      54.610
# 122                       Independent, Happy, Outgoing        177      39.370
# 264                       Friendly, Fearless, Obedient         36      58.420
# 28                          Gentle, Faithful, Obedient        124      60.960
# 121                      Affectionate, Confident, Bold        115      58.420
# 138                        Playful, Hardworking, Brave        159      53.340
# 115                 Friendly, Smart, Willing to Please          9      53.340
# 129                Friendly, Outgoing, People-Oriented        189      48.260
# 109                 Cheerful, Optimistic, Good-Humored         91      55.880
# 203                Affectionate, Adventurous, Athletic         50      43.180
# 124                               Smart, Patient, Calm         66      63.500
# 243  Playful but also Work-Oriented. Very Active an...        153      40.005
# 117                  Affectionate, Eager, Enthusiastic         63      55.880
# 153                         Friendly, Active, Outgoing          1      54.610
# 50             Affectionate, Courageous, Strong-Willed         84      59.690
# 165                 Good-Natured, Intelligent, Devoted         34      33.020
# 26                            Friendly, Curious, Merry          6      33.020
# 3              Courageous, Dignified, Profoundly Loyal         47      60.960
# 113                 Courageous, Intelligent, Vivacious        134      43.180
# 40                         Intelligent, Calm, Powerful        118      66.040
# 193                          Confident, Clever, Lively        170      43.180
# 221                        Adaptable, Friendly, Gentle         59      48.260
#
#      max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 57       52.070   13.607771   18.143695            12.0            14.0  ...
# 46       55.880   13.607771   24.947580            12.0            15.0  ...
# 136      68.580   27.215542   31.751466            12.0            15.0  ...
# 216      30.480    4.082331    6.803886            12.0            14.0  ...
# 180      53.340   15.875733   22.679619            12.0            14.0  ...
# 271      60.960   15.875733   31.751466            12.0            15.0  ...
# 184      35.560    5.896701    7.711070            13.0            15.0  ...
# 108      50.800    9.071847   14.968548            13.0            15.0  ...
# 120      60.960   24.947580   34.019428            10.0            12.0  ...
# 122      45.720   18.143695   20.411657            13.0            15.0  ...
# 264      68.580   24.947580   40.823313            10.0            13.0  ...
# 28       69.850   31.751466   49.895161            10.0            12.0  ...
# 121      68.580   20.411657   36.287390            12.0            13.0  ...
# 138      60.960   20.411657   30.844281            12.0            13.0  ...
# 115      63.500   20.411657   31.751466            10.0            12.0  ...
# 129      53.340   20.411657   27.215542            12.0            15.0  ...
# 109      62.230   27.215542   31.751466             8.0            10.0  ...
# 203      58.420   15.875733   27.215542            11.0            13.0  ...
# 124      81.280   38.555351   45.359237            10.0            12.0  ...
# 243      50.165   14.061363   22.226026            12.0            14.0  ...
# 117      66.040   22.679619   31.751466            14.0            16.0  ...
# 153      62.230   24.947580   36.287390            10.0            12.0  ...
# 50       69.850   31.751466   49.895161            10.0            12.0  ...
# 165      45.720    9.071847   18.143695            12.0            13.0  ...
# 26       38.100    5.896701   13.607771            10.0            15.0  ...
# 3        71.120   31.751466   58.967008            10.0            13.0  ...
# 113      50.800   11.339809   20.411657            12.0            14.0  ...
# 40       76.200   36.287390   58.967008            10.0            12.0  ...
# 193      50.800   13.607771   22.679619            12.0            14.0  ...
# 221      59.690   15.875733   29.483504            12.0            14.0  ...
#
#     energy_level_value   energy_level_category trainability_value  \
# 57                 1.0  Needs Lots of Activity                1.0
# 46                 1.0  Needs Lots of Activity                1.0
# 136                1.0  Needs Lots of Activity                0.6
# 216                1.0  Needs Lots of Activity                0.6
# 180                1.0  Needs Lots of Activity                0.8
# 271                1.0  Needs Lots of Activity                0.6
# 184                1.0  Needs Lots of Activity                0.6
# 108                1.0  Needs Lots of Activity                0.6
# 120                1.0  Needs Lots of Activity                1.0
# 122                1.0  Needs Lots of Activity                0.4
# 264                1.0  Needs Lots of Activity                1.0
# 28                 1.0  Needs Lots of Activity                0.8
# 121                1.0  Needs Lots of Activity                0.4
# 138                1.0  Needs Lots of Activity                0.8
# 115                1.0  Needs Lots of Activity                1.0
# 129                1.0  Needs Lots of Activity                0.8
# 109                1.0  Needs Lots of Activity                1.0
# 203                0.8               Energetic                0.8
# 124                1.0  Needs Lots of Activity                0.4
# 243                0.8               Energetic                1.0
# 117                1.0  Needs Lots of Activity                1.0
# 153                1.0  Needs Lots of Activity                1.0
# 50                 0.8               Energetic                0.6
# 165                0.8               Energetic                1.0
# 26                 0.8               Energetic                0.6
# 3                  0.8               Energetic                1.0
# 113                1.0  Needs Lots of Activity                0.6
# 40                 0.8               Energetic                0.8
# 193                0.8               Energetic                0.2
# 221                0.8               Energetic                0.4
#
#      trainability_category demeanor_value        demeanor_category weight_avg  \
# 57         Eager to Please            0.8                 Friendly  15.875733
# 46         Eager to Please            0.4  Reserved with Strangers  19.277676
# 136              Agreeable            1.0                 Outgoing  29.483504
# 216              Agreeable            0.8                 Friendly   5.443108
# 180          Easy Training            0.8                 Friendly  19.277676
# 271              Agreeable            0.6         Alert/Responsive  23.813599
# 184              Agreeable            0.8                 Friendly   6.803886
# 108              Agreeable            0.8                 Friendly  12.020198
# 120        Eager to Please            0.8                 Friendly  29.483504
# 122            Independent            0.8                 Friendly  19.277676
# 264        Eager to Please            0.8                 Friendly  32.885447
# 28           Easy Training            0.4  Reserved with Strangers  40.823313
# 121            Independent            0.4  Reserved with Strangers  28.349523
# 138          Easy Training            0.4  Reserved with Strangers  25.627969
# 115        Eager to Please            0.8                 Friendly  26.081561
# 129          Easy Training            0.8                 Friendly  23.813599
# 109        Eager to Please            0.8                 Friendly  29.483504
# 203          Easy Training            0.6         Alert/Responsive  21.545638
# 124            Independent            0.4  Reserved with Strangers  41.957294
# 243        Eager to Please            0.4  Reserved with Strangers  18.143695
# 117        Eager to Please            0.4  Reserved with Strangers  27.215542
# 153        Eager to Please            1.0                 Outgoing  30.617485
# 50               Agreeable            0.6         Alert/Responsive  40.823313
# 165        Eager to Please            0.8                 Friendly  13.607771
# 26               Agreeable            0.8                 Friendly   9.752236
# 3          Eager to Please            0.6         Alert/Responsive  45.359237
# 113              Agreeable            0.6         Alert/Responsive  15.875733
# 40           Easy Training            0.4  Reserved with Strangers  47.627199
# 193        May be Stubborn            0.2               Aloof/Wary  18.143695
# 221            Independent            0.8                 Friendly  22.679619
#
#      height_avg life_expectancy_avg  KNN_distance
# 57       48.260                13.0     14.702164
# 46       50.800                13.5     14.815852
# 136      66.040                13.5     14.861531
# 216      27.940                13.0     15.018177
# 180      48.260                13.0     15.042036
# 271      55.880                13.5     15.053256
# 184      34.290                14.0     15.076240
# 108      45.085                14.0     15.154976
# 120      57.785                11.0     15.187216
# 122      42.545                14.0     15.213615
# 264      63.500                11.5     15.216483
# 28       65.405                11.0     15.229651
# 121      63.500                12.5     15.287744
# 138      57.150                12.5     15.298456
# 115      58.420                11.0     15.306915
# 129      50.800                13.5     15.330496
# 109      59.055                 9.0     15.384477
# 203      50.800                12.0     15.387425
# 124      72.390                11.0     15.396793
# 243      45.085                13.0     15.404462
# 117      60.960                15.0     15.470233
# 153      58.420                11.0     15.474520
# 50       64.770                11.0     15.484684
# 165      39.370                12.5     15.624975
# 26       35.560                12.5     15.634442
# 3        66.040                11.5     15.648567
# 113      46.990                13.0     15.714967
# 40       71.120                11.0     15.751005
# 193      46.990                13.0     15.765838
# 221      53.975                13.0     15.770231
#
# [30 rows x 25 columns]
